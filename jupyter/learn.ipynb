# %%
import pandas as pd

movie_info = pd.read_csv("Movie Interests.csv")
movie_info
# Out:
#     Age Gender   Interest
# 0     8      m  Animation
# 1    11      m  Animation
# 2    12      m  Animation
# 3    16      m     Action
# 4    18      m     Action
# 5    19      m     Action
# 6    23      m      Drama
# 7    26      m      Drama
# 8    27      m      Drama
# 9     7      f  Animation
# 10    9      f  Animation
# 11   10      f  Animation
# 12   26      f     Action
# 13   27      f     Action
# 14   30      f     Action
# 15   31      f      Drama
# 16   34      f      Drama
# 17   35      f      Drama

# %%
input_dataset = movie_info.drop(columns=['Interest'])
input_dataset
# Out:
#     Age Gender
# 0     8      m
# 1    11      m
# 2    12      m
# 3    16      m
# 4    18      m
# 5    19      m
# 6    23      m
# 7    26      m
# 8    27      m
# 9     7      f
# 10    9      f
# 11   10      f
# 12   26      f
# 13   27      f
# 14   30      f
# 15   31      f
# 16   34      f
# 17   35      f

# %%
output_dataset = movie_info["Interest"]
output_dataset
# Out:
# 0     Animation
# 1     Animation
# 2     Animation
# 3        Action
# 4        Action
# 5        Action
# 6         Drama
# 7         Drama
# 8         Drama
# 9     Animation
# 10    Animation
# 11    Animation
# 12       Action
# 13       Action
# 14       Action
# 15        Drama
# 16        Drama
# 17        Drama
# Name: Interest, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier
movie_model = DecisionTreeClassifier( )
movie_model.fit(input_dataset,output_dataset)
movie_interest = movie_model.predict([[9,'m'],[33,'f']])
movie_interest
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15792\4283339686.py in ?()
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 movie_model = DecisionTreeClassifier( )
# ----> 3 movie_model.fit(input_dataset,output_dataset)
#       4 movie_interest = movie_model.predict([[9,'m'],[33,'f']])
#       5 movie_interest
#
# c:\Users\vjnav\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ...
